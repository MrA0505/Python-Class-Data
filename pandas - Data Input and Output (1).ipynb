# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\HP P DTS'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 12AD-B436
#
#  Directory of C:\Users\HP P DTS
#
# 29-01-2020  15:58    <DIR>          .
# 29-01-2020  15:58    <DIR>          ..
# 05-09-2019  17:40    <DIR>          .anaconda
# 12-10-2019  07:11                13 .bash_history
# 13-01-2020  14:25    <DIR>          .conda
# 13-01-2020  14:20               103 .condarc
# 05-09-2019  17:41    <DIR>          .config
# 29-12-2019  11:38    <DIR>          .cufflinks
# 02-09-2019  17:36               126 .defaults-0.1.0.ini
# 12-10-2019  10:28               249 .gitconfig
# 29-01-2020  15:58    <DIR>          .ipynb_checkpoints
# 05-09-2019  17:41    <DIR>          .ipython
# 28-09-2019  15:24    <DIR>          .jupyter
# 05-11-2019  19:45    <DIR>          .keras
# 16-11-2019  11:00    <DIR>          .matplotlib
# 13-11-2019  21:10    <DIR>          .PyCharmCE2019.2
# 28-11-2019  16:30               133 .python_history
# 05-09-2019  18:29                 0 .Rhistory
# ...

# %%
cd desktop
# Out:
# C:\Users\HP P DTS\desktop

# %%
ls
# Out:
#   File "<ipython-input-6-de376755d7cf>", line 2
#     cd "Python Classes"
#                       ^
# SyntaxError: invalid syntax

# %%
cd "Python Classes"
# Out:
# C:\Users\HP P DTS\desktop\Python Classes

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 12AD-B436
#
#  Directory of C:\Users\HP P DTS\desktop\Python Classes
#
# 13-01-2020  21:30    <DIR>          .
# 13-01-2020  21:30    <DIR>          ..
# 26-12-2019  13:16    <DIR>          .ipynb_checkpoints
# 13-11-2019  07:16             1,493 add multiple list on based of index.txt
# 04-12-2019  19:32            14,723 Basic Python - Test for Anurag.docx
# 08-09-2019  14:38            13,807 Basic Python - Test Paper.docx
# 22-11-2019  22:17            17,207 Basic Python Test Paper - If - else.docx
# 29-01-2020  12:45    <DIR>          DataSet
# 07-01-2020  14:09            16,808 DateTime Format.docx
# 30-12-2019  14:07               170 employee.csv
# 12-12-2019  12:29            20,614 L1 -Python Test.docx
# 15-11-2019  21:22            13,945 Logistic Regression Portfolio Project.docx
# 26-11-2019  22:31            15,564 Natural Language Processing - Steps.docx
# ...

# %%
cd DataSet
# Out:
# C:\Users\HP P DTS\desktop\Python Classes\DataSet

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 12AD-B436
#
#  Directory of C:\Users\HP P DTS\desktop\Python Classes\DataSet
#
# 29-01-2020  12:45    <DIR>          .
# 29-01-2020  12:45    <DIR>          ..
# 29-09-2019  20:23    <DIR>          .ipynb_checkpoints
# 30-08-2018  11:54        18,379,159 911.csv
# 30-08-2018  11:54           107,424 advertising.csv
# 11-01-2020  22:26               764 air-passengers.zip
# 08-01-2020  07:22            18,827 apple.csv
# 10-11-2019  20:50         4,882,916 bank.csv
# 12-10-2019  08:29            58,368 cars.xls
# 12-10-2019  07:49    <DIR>          car-sales
# 12-10-2019  07:49             6,987 car-sales.zip
# 30-08-2018  11:54           194,323 Classified Data
# 07-01-2020  13:38               472 Company_DS.csv
# 10-01-2020  21:58            17,071 CSV.csv
# 10-11-2019  21:01            11,550 customer_reviews.csv
# 24-12-2019  12:54         3,181,459 Data science - assignment.xlsx
# ...

# %%
df_comp_loc=pd.read_csv(r'C:\Users\HP P DTS\Desktop\Python Classes\DataSet\Missing_value.csv')

# %%
df_comp_loc
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
pwd
# Out:
# 'C:\\Users\\HP P DTS\\desktop\\Python Classes\\DataSet'

# %%
df_ms=pd.read_csv('Missing_value.csv')

# %%
df_ms
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
# Missing value
# fillna
# dropna
# interpolate
# replace

# %%
# Missing value checked
# isnull() -> NaN - True, other NaN -> False
# notnull() -> Other NaN/NaT - True , NaN/NaT -> False

# %%
df_ms.isnull()
# Out:
#      Days  Sleep  Study   Play    Eat
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False   True  False   True   True
# 3   False  False   True  False   True
# 4   False  False  False  False  False
# 5   False  False  False  False   True
# 6   False  False   True  False  False
# 7   False   True  False  False  False
# 8   False  False  False  False   True
# 9   False  False  False  False  False
# 10  False   True  False  False  False
# 11  False  False  False  False   True
# 12  False  False  False  False  False
# 13  False  False   True  False  False
# 14  False  False  False  False  False
# 15  False   True  False   True  False

# %%
df_ms.notnull()
# Out:
#     Days  Sleep  Study   Play    Eat
# 0   True   True   True   True   True
# 1   True   True   True   True   True
# 2   True  False   True  False  False
# 3   True   True  False   True  False
# 4   True   True   True   True   True
# 5   True   True   True   True  False
# 6   True   True  False   True   True
# 7   True  False   True   True   True
# 8   True   True   True   True  False
# 9   True   True   True   True   True
# 10  True  False   True   True   True
# 11  True   True   True   True  False
# 12  True   True   True   True   True
# 13  True   True  False   True   True
# 14  True   True   True   True   True
# 15  True  False   True  False   True

# %%
df_ms.isnull().count()
# Out:
# Days     16
# Sleep    16
# Study    16
# Play     16
# Eat      16
# dtype: int64

# %%
df_ms.count() # NaN is ignored
# Out:
# Days     16
# Sleep    12
# Study    13
# Play     14
# Eat      11
# dtype: int64

# %%
df_ms['Days'].value_counts()
# Out:
# 10-01-2020    1
# 18-01-2020    1
# 26-01-2020    1
# 22-01-2020    1
# 08-01-2020    1
# 16-01-2020    1
# 01-01-2020    1
# 25-01-2020    1
# 09-01-2020    1
# 03-01-2020    1
# 06-01-2020    1
# 19-01-2020    1
# 11-01-2020    1
# 17-01-2020    1
# 15-01-2020    1
# 02-01-2020    1
# Name: Days, dtype: int64

# %%
df_ms['Eat'].value_counts()
# Out:
# Salad       3
# Fruits      2
# Bread       1
# Soup        1
# Rice        1
# Chicken     1
# Mashroom    1
# Biryani     1
# Name: Eat, dtype: int64

# %%
df_ms['Eat'].isnull().value_counts()
# Out:
# False    11
# True      5
# Name: Eat, dtype: int64

# %%
df_ms.replace(np.NaN,'Salad')
# Out:
#           Days  Sleep  Study   Play       Eat
# 0   01-01-2020      9      8      4  Mashroom
# 1   02-01-2020      8      6      3      Rice
# 2   03-01-2020  Salad      5  Salad     Salad
# 3   06-01-2020      8  Salad      5     Salad
# 4   08-01-2020      7      6      5   Biryani
# 5   09-01-2020     10      3      2     Salad
# 6   10-01-2020      8  Salad      5   Chicken
# 7   11-01-2020  Salad      7      4      Soup
# 8   15-01-2020     12      5      7     Salad
# 9   16-01-2020     11      5      6    Fruits
# 10  17-01-2020  Salad      5      6     Salad
# 11  18-01-2020     13      4      2     Salad
# 12  19-01-2020     10      6      4    Fruits
# 13  22-01-2020     12  Salad      6     Bread
# 14  25-01-2020     10      6      4     Salad
# 15  26-01-2020  Salad      5  Salad     Salad

# %%
dic={'Sleep':12,'Study':4,'Play':2,'Eat':'Penauts'}
df_ms.replace(np.NaN,dic)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020   12.0    5.0   2.0   Penauts
# 3   06-01-2020    8.0    4.0   5.0   Penauts
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0   Penauts
# 6   10-01-2020    8.0    4.0   5.0   Chicken
# 7   11-01-2020   12.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0   Penauts
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   12.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0   Penauts
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    4.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   12.0    5.0   2.0     Salad

# %%
df_ms
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df2=pd.read_csv('Missing_value.csv')

# %%
df2
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020 -555.0    5.0   NaN   Nothing
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0 -555.0   5.0   Chicken
# 7   11-01-2020 -555.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0   Nothing
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df2.replace(-555,0)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    0.0    5.0   NaN   Nothing
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    0.0   5.0   Chicken
# 7   11-01-2020    0.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0   Nothing
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df2.replace([-555,'Nothing'],[0,'Veg-Polau'])
# Out:
#           Days  Sleep  Study  Play        Eat
# 0   01-01-2020    9.0    8.0   4.0   Mashroom
# 1   02-01-2020    8.0    6.0   3.0       Rice
# 2   03-01-2020    0.0    5.0   NaN  Veg-Polau
# 3   06-01-2020    8.0    NaN   5.0        NaN
# 4   08-01-2020    7.0    6.0   5.0    Biryani
# 5   09-01-2020   10.0    3.0   2.0        NaN
# 6   10-01-2020    8.0    0.0   5.0    Chicken
# 7   11-01-2020    0.0    7.0   4.0       Soup
# 8   15-01-2020   12.0    5.0   7.0  Veg-Polau
# 9   16-01-2020   11.0    5.0   6.0     Fruits
# 10  17-01-2020    NaN    5.0   6.0      Salad
# 11  18-01-2020   13.0    4.0   2.0        NaN
# 12  19-01-2020   10.0    6.0   4.0     Fruits
# 13  22-01-2020   12.0    NaN   6.0      Bread
# 14  25-01-2020   10.0    6.0   4.0      Salad
# 15  26-01-2020    NaN    5.0   NaN      Salad

# %%
#fillna()

df2
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020 -555.0    5.0   NaN   Nothing
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0 -555.0   5.0   Chicken
# 7   11-01-2020 -555.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0   Nothing
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df3=pd.read_csv('Missing_value.csv')

# %%
df3
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df3.fillna(value='Python')
# Out:
#           Days   Sleep   Study    Play       Eat
# 0   01-01-2020       9       8       4  Mashroom
# 1   02-01-2020       8       6       3      Rice
# 2   03-01-2020  Python       5  Python    Python
# 3   06-01-2020       8  Python       5    Python
# 4   08-01-2020       7       6       5   Biryani
# 5   09-01-2020      10       3       2    Python
# 6   10-01-2020       8  Python       5   Chicken
# 7   11-01-2020  Python       7       4      Soup
# 8   15-01-2020      12       5       7    Python
# 9   16-01-2020      11       5       6    Fruits
# 10  17-01-2020  Python       5       6     Salad
# 11  18-01-2020      13       4       2    Python
# 12  19-01-2020      10       6       4    Fruits
# 13  22-01-2020      12  Python       6     Bread
# 14  25-01-2020      10       6       4     Salad
# 15  26-01-2020  Python       5  Python     Salad

# %%
df3
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df3.fillna(value=888)
# Out:
#           Days  Sleep  Study   Play       Eat
# 0   01-01-2020    9.0    8.0    4.0  Mashroom
# 1   02-01-2020    8.0    6.0    3.0      Rice
# 2   03-01-2020  888.0    5.0  888.0       888
# 3   06-01-2020    8.0  888.0    5.0       888
# 4   08-01-2020    7.0    6.0    5.0   Biryani
# 5   09-01-2020   10.0    3.0    2.0       888
# 6   10-01-2020    8.0  888.0    5.0   Chicken
# 7   11-01-2020  888.0    7.0    4.0      Soup
# 8   15-01-2020   12.0    5.0    7.0       888
# 9   16-01-2020   11.0    5.0    6.0    Fruits
# 10  17-01-2020  888.0    5.0    6.0     Salad
# 11  18-01-2020   13.0    4.0    2.0       888
# 12  19-01-2020   10.0    6.0    4.0    Fruits
# 13  22-01-2020   12.0  888.0    6.0     Bread
# 14  25-01-2020   10.0    6.0    4.0     Salad
# 15  26-01-2020  888.0    5.0  888.0     Salad

# %%
df3.fillna(value=45,axis=1)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020   45.0    5.0  45.0        45
# 3   06-01-2020    8.0   45.0   5.0        45
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0        45
# 6   10-01-2020    8.0   45.0   5.0   Chicken
# 7   11-01-2020   45.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0        45
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   45.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0        45
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0   45.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   45.0    5.0  45.0     Salad

# %%
mean_val=df3['Sleep'].mean()

# %%
mean_val
# Out:
# 9.833333333333334

# %%
df3.fillna(value=mean_val)
# Out:
#           Days      Sleep     Study      Play       Eat
# 0   01-01-2020   9.000000  8.000000  4.000000  Mashroom
# 1   02-01-2020   8.000000  6.000000  3.000000      Rice
# 2   03-01-2020   9.833333  5.000000  9.833333   9.83333
# 3   06-01-2020   8.000000  9.833333  5.000000   9.83333
# 4   08-01-2020   7.000000  6.000000  5.000000   Biryani
# 5   09-01-2020  10.000000  3.000000  2.000000   9.83333
# 6   10-01-2020   8.000000  9.833333  5.000000   Chicken
# 7   11-01-2020   9.833333  7.000000  4.000000      Soup
# 8   15-01-2020  12.000000  5.000000  7.000000   9.83333
# 9   16-01-2020  11.000000  5.000000  6.000000    Fruits
# 10  17-01-2020   9.833333  5.000000  6.000000     Salad
# 11  18-01-2020  13.000000  4.000000  2.000000   9.83333
# 12  19-01-2020  10.000000  6.000000  4.000000    Fruits
# 13  22-01-2020  12.000000  9.833333  6.000000     Bread
# 14  25-01-2020  10.000000  6.000000  4.000000     Salad
# 15  26-01-2020   9.833333  5.000000  9.833333     Salad

# %%
df3.fillna(df3['Sleep'].mean())
# Out:
#           Days      Sleep     Study      Play       Eat
# 0   01-01-2020   9.000000  8.000000  4.000000  Mashroom
# 1   02-01-2020   8.000000  6.000000  3.000000      Rice
# 2   03-01-2020   9.833333  5.000000  9.833333   9.83333
# 3   06-01-2020   8.000000  9.833333  5.000000   9.83333
# 4   08-01-2020   7.000000  6.000000  5.000000   Biryani
# 5   09-01-2020  10.000000  3.000000  2.000000   9.83333
# 6   10-01-2020   8.000000  9.833333  5.000000   Chicken
# 7   11-01-2020   9.833333  7.000000  4.000000      Soup
# 8   15-01-2020  12.000000  5.000000  7.000000   9.83333
# 9   16-01-2020  11.000000  5.000000  6.000000    Fruits
# 10  17-01-2020   9.833333  5.000000  6.000000     Salad
# 11  18-01-2020  13.000000  4.000000  2.000000   9.83333
# 12  19-01-2020  10.000000  6.000000  4.000000    Fruits
# 13  22-01-2020  12.000000  9.833333  6.000000     Bread
# 14  25-01-2020  10.000000  6.000000  4.000000     Salad
# 15  26-01-2020   9.833333  5.000000  9.833333     Salad

# %%
df3.fillna(method='ffill') # ffill => Vertical fill top to bottom
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   3.0      Rice
# 3   06-01-2020    8.0    5.0   5.0      Rice
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0   Biryani
# 6   10-01-2020    8.0    3.0   5.0   Chicken
# 7   11-01-2020    8.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0      Soup
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   11.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0     Salad
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   10.0    5.0   4.0     Salad

# %%
df3.fillna(method='bfill')
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   5.0   Biryani
# 3   06-01-2020    8.0    6.0   5.0   Biryani
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0   Chicken
# 6   10-01-2020    8.0    7.0   5.0   Chicken
# 7   11-01-2020   12.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0    Fruits
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   13.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0    Fruits
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df3.fillna(method='bfill') # vertical fill bottom to top
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   5.0   Biryani
# 3   06-01-2020    8.0    6.0   5.0   Biryani
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0   Chicken
# 6   10-01-2020    8.0    7.0   5.0   Chicken
# 7   11-01-2020   12.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0    Fruits
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   13.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0    Fruits
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df3.fillna(method='bfill',axis='columns') # horizontal right to left
# Out:
#           Days Sleep Study   Play       Eat
# 0   01-01-2020     9     8      4  Mashroom
# 1   02-01-2020     8     6      3      Rice
# 2   03-01-2020     5     5    NaN       NaN
# 3   06-01-2020     8     5      5       NaN
# 4   08-01-2020     7     6      5   Biryani
# 5   09-01-2020    10     3      2       NaN
# 6   10-01-2020     8     5      5   Chicken
# 7   11-01-2020     7     7      4      Soup
# 8   15-01-2020    12     5      7       NaN
# 9   16-01-2020    11     5      6    Fruits
# 10  17-01-2020     5     5      6     Salad
# 11  18-01-2020    13     4      2       NaN
# 12  19-01-2020    10     6      4    Fruits
# 13  22-01-2020    12     6      6     Bread
# 14  25-01-2020    10     6      4     Salad
# 15  26-01-2020     5     5  Salad     Salad

# %%
df3.fillna(method='ffill',axis=1)
# Out:
#           Days       Sleep Study Play       Eat
# 0   01-01-2020           9     8    4  Mashroom
# 1   02-01-2020           8     6    3      Rice
# 2   03-01-2020  03-01-2020     5    5         5
# 3   06-01-2020           8     8    5         5
# 4   08-01-2020           7     6    5   Biryani
# 5   09-01-2020          10     3    2         2
# 6   10-01-2020           8     8    5   Chicken
# 7   11-01-2020  11-01-2020     7    4      Soup
# 8   15-01-2020          12     5    7         7
# 9   16-01-2020          11     5    6    Fruits
# 10  17-01-2020  17-01-2020     5    6     Salad
# 11  18-01-2020          13     4    2         2
# 12  19-01-2020          10     6    4    Fruits
# 13  22-01-2020          12    12    6     Bread
# 14  25-01-2020          10     6    4     Salad
# 15  26-01-2020  26-01-2020     5    5     Salad

# %%
df4=pd.read_csv('Missing_value.csv')

# %%
df4
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad
# 16  27-01-2020    NaN    NaN   NaN       NaN
# 17  28-01-2020    NaN    NaN   NaN       NaN

# %%
#dropna() -> rows will be deleted
df4.dropna()
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 14  25-01-2020   10.0    6.0   4.0     Salad

# %%
df4.dropna(thresh=2)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    NaN    5.0   NaN       NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    NaN   5.0   Chicken
# 7   11-01-2020    NaN    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020    NaN    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    NaN   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020    NaN    5.0   NaN     Salad

# %%
df4.dropna(axis=1)
# Out:
#           Days
# 0   01-01-2020
# 1   02-01-2020
# 2   03-01-2020
# 3   06-01-2020
# 4   08-01-2020
# 5   09-01-2020
# 6   10-01-2020
# 7   11-01-2020
# 8   15-01-2020
# 9   16-01-2020
# 10  17-01-2020
# 11  18-01-2020
# 12  19-01-2020
# 13  22-01-2020
# 14  25-01-2020
# 15  26-01-2020
# 16  27-01-2020
# 17  28-01-2020

# %%
df4.dropna(axis=1,thresh=12)
# Out:
#           Days  Sleep  Study  Play
# 0   01-01-2020    9.0    8.0   4.0
# 1   02-01-2020    8.0    6.0   3.0
# 2   03-01-2020    NaN    5.0   NaN
# 3   06-01-2020    8.0    NaN   5.0
# 4   08-01-2020    7.0    6.0   5.0
# 5   09-01-2020   10.0    3.0   2.0
# 6   10-01-2020    8.0    NaN   5.0
# 7   11-01-2020    NaN    7.0   4.0
# 8   15-01-2020   12.0    5.0   7.0
# 9   16-01-2020   11.0    5.0   6.0
# 10  17-01-2020    NaN    5.0   6.0
# 11  18-01-2020   13.0    4.0   2.0
# 12  19-01-2020   10.0    6.0   4.0
# 13  22-01-2020   12.0    NaN   6.0
# 14  25-01-2020   10.0    6.0   4.0
# 15  26-01-2020    NaN    5.0   NaN
# 16  27-01-2020    NaN    NaN   NaN
# 17  28-01-2020    NaN    NaN   NaN

# %%
df4.interpolate()
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   4.0       NaN
# 3   06-01-2020    8.0    5.5   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    5.0   5.0   Chicken
# 7   11-01-2020   10.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   12.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   10.0    5.0   4.0     Salad
# 16  27-01-2020   10.0    5.0   4.0       NaN
# 17  28-01-2020   10.0    5.0   4.0       NaN

# %%
df4.interpolate(limit=1)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   4.0       NaN
# 3   06-01-2020    8.0    5.5   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    5.0   5.0   Chicken
# 7   11-01-2020   10.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   12.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   10.0    5.0   4.0     Salad
# 16  27-01-2020    NaN    5.0   NaN       NaN
# 17  28-01-2020    NaN    NaN   NaN       NaN

# %%
df4.interpolate(limit=2)
# Out:
#           Days  Sleep  Study  Play       Eat
# 0   01-01-2020    9.0    8.0   4.0  Mashroom
# 1   02-01-2020    8.0    6.0   3.0      Rice
# 2   03-01-2020    8.0    5.0   4.0       NaN
# 3   06-01-2020    8.0    5.5   5.0       NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani
# 5   09-01-2020   10.0    3.0   2.0       NaN
# 6   10-01-2020    8.0    5.0   5.0   Chicken
# 7   11-01-2020   10.0    7.0   4.0      Soup
# 8   15-01-2020   12.0    5.0   7.0       NaN
# 9   16-01-2020   11.0    5.0   6.0    Fruits
# 10  17-01-2020   12.0    5.0   6.0     Salad
# 11  18-01-2020   13.0    4.0   2.0       NaN
# 12  19-01-2020   10.0    6.0   4.0    Fruits
# 13  22-01-2020   12.0    6.0   6.0     Bread
# 14  25-01-2020   10.0    6.0   4.0     Salad
# 15  26-01-2020   10.0    5.0   4.0     Salad
# 16  27-01-2020   10.0    5.0   4.0       NaN
# 17  28-01-2020    NaN    5.0   NaN       NaN

# %%
df3['Total_Hour']=df4['Study'] + df4['Sleep'] + df4['Play']

# %%
df3.columns
# Out:
# Index(['Days', 'Sleep', 'Study', 'Play', 'Eat'], dtype='object')

# %%
df3
# Out:
#           Days  Sleep  Study  Play       Eat  Total_Hour
# 0   01-01-2020    9.0    8.0   4.0  Mashroom        21.0
# 1   02-01-2020    8.0    6.0   3.0      Rice        17.0
# 2   03-01-2020    NaN    5.0   NaN       NaN         NaN
# 3   06-01-2020    8.0    NaN   5.0       NaN         NaN
# 4   08-01-2020    7.0    6.0   5.0   Biryani        18.0
# 5   09-01-2020   10.0    3.0   2.0       NaN        15.0
# 6   10-01-2020    8.0    NaN   5.0   Chicken         NaN
# 7   11-01-2020    NaN    7.0   4.0      Soup         NaN
# 8   15-01-2020   12.0    5.0   7.0       NaN        24.0
# 9   16-01-2020   11.0    5.0   6.0    Fruits        22.0
# 10  17-01-2020    NaN    5.0   6.0     Salad         NaN
# 11  18-01-2020   13.0    4.0   2.0       NaN        19.0
# 12  19-01-2020   10.0    6.0   4.0    Fruits        20.0
# 13  22-01-2020   12.0    NaN   6.0     Bread         NaN
# 14  25-01-2020   10.0    6.0   4.0     Salad        20.0
# ...

# %%
df4.describe()
# Out:
#            Sleep      Study       Play
# count  12.000000  13.000000  14.000000
# mean    9.833333   5.461538   4.500000
# std     1.898963   1.265924   1.506397
# min     7.000000   3.000000   2.000000
# 25%     8.000000   5.000000   4.000000
# 50%    10.000000   5.000000   4.500000
# 75%    11.250000   6.000000   5.750000
# max    13.000000   8.000000   7.000000

# %%
# displays rows from top and bottom
# top rows head() -> default 5 rows display
# bottom rows tail() -> default 5 rows display

# %%
df4.head()
# Out:
#          Days  Sleep  Study  Play       Eat
# 0  01-01-2020    9.0    8.0   4.0  Mashroom
# 1  02-01-2020    8.0    6.0   3.0      Rice
# 2  03-01-2020    NaN    5.0   NaN       NaN
# 3  06-01-2020    8.0    NaN   5.0       NaN
# 4  08-01-2020    7.0    6.0   5.0   Biryani

# %%
df4.tail()
# Out:
#           Days  Sleep  Study  Play    Eat
# 13  22-01-2020   12.0    NaN   6.0  Bread
# 14  25-01-2020   10.0    6.0   4.0  Salad
# 15  26-01-2020    NaN    5.0   NaN  Salad
# 16  27-01-2020    NaN    NaN   NaN    NaN
# 17  28-01-2020    NaN    NaN   NaN    NaN

# %%
df4.head(8)
# Out:
#          Days  Sleep  Study  Play       Eat
# 0  01-01-2020    9.0    8.0   4.0  Mashroom
# 1  02-01-2020    8.0    6.0   3.0      Rice
# 2  03-01-2020    NaN    5.0   NaN       NaN
# 3  06-01-2020    8.0    NaN   5.0       NaN
# 4  08-01-2020    7.0    6.0   5.0   Biryani
# 5  09-01-2020   10.0    3.0   2.0       NaN
# 6  10-01-2020    8.0    NaN   5.0   Chicken
# 7  11-01-2020    NaN    7.0   4.0      Soup

# %%
df4.tail(10)
# Out:
#           Days  Sleep  Study  Play     Eat
# 8   15-01-2020   12.0    5.0   7.0     NaN
# 9   16-01-2020   11.0    5.0   6.0  Fruits
# 10  17-01-2020    NaN    5.0   6.0   Salad
# 11  18-01-2020   13.0    4.0   2.0     NaN
# 12  19-01-2020   10.0    6.0   4.0  Fruits
# 13  22-01-2020   12.0    NaN   6.0   Bread
# 14  25-01-2020   10.0    6.0   4.0   Salad
# 15  26-01-2020    NaN    5.0   NaN   Salad
# 16  27-01-2020    NaN    NaN   NaN     NaN
# 17  28-01-2020    NaN    NaN   NaN     NaN

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
# Days     18 non-null object
# Sleep    12 non-null float64
# Study    13 non-null float64
# Play     14 non-null float64
# Eat      11 non-null object
# dtypes: float64(3), object(2)
# memory usage: 800.0+ bytes

# %%
df4.shape
# Out:
# (18, 5)
