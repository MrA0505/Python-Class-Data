# %%
import pandas as pd

# %%
appl=pd.read_csv(r'C:\Users\HP P DTS\Desktop\Machine Learning\Data Set\AAPL.csv')

# %%
appl.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  115.800003  116.330002  114.760002  116.150002  110.691154
# 1  2017-01-04  115.849998  116.510002  115.750000  116.019997  110.567276
# 2  2017-01-05  115.919998  116.860001  115.809998  116.610001  111.129562
# 3  2017-01-06  116.779999  118.160004  116.470001  117.910004  112.368469
# 4  2017-01-09  117.949997  119.430000  117.940002  118.989998  113.397697
#
#      Volume
# 0  28781900
# 1  21118100
# 2  22193600
# 3  31751900
# 4  33561900

# %%
appl['Date']=pd.to_datetime(appl['Date'])

# %%
type(appl['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
appl.set_index(appl['Date'],inplace=True)

# %%
appl.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2017-01-03 2017-01-03  115.800003  116.330002  114.760002  116.150002
# 2017-01-04 2017-01-04  115.849998  116.510002  115.750000  116.019997
# 2017-01-05 2017-01-05  115.919998  116.860001  115.809998  116.610001
# 2017-01-06 2017-01-06  116.779999  118.160004  116.470001  117.910004
# 2017-01-09 2017-01-09  117.949997  119.430000  117.940002  118.989998
#
#              Adj Close    Volume
# Date
# 2017-01-03  110.691154  28781900
# 2017-01-04  110.567276  21118100
# 2017-01-05  111.129562  22193600
# 2017-01-06  112.368469  31751900
# 2017-01-09  113.397697  33561900

# %%
appl.drop('Date',axis='columns',inplace=True)

# %%
appl
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  110.691154
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  110.567276
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  111.129562
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  112.368469
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  113.397697
# 2017-01-10  118.769997  119.379997  118.300003  119.110001  113.512070
# 2017-01-11  118.739998  119.930000  118.599998  119.750000  114.121986
# 2017-01-12  118.900002  119.300003  118.209999  119.250000  113.645454
# 2017-01-13  119.110001  119.620003  118.809998  119.040001  113.445343
# 2017-01-17  118.339996  120.239998  118.220001  120.000000  114.360237
# 2017-01-18  120.000000  120.500000  119.709999  119.989998  114.350693
# 2017-01-19  119.400002  120.089996  119.370003  119.779999  114.150558
# ...

# %%
appl.loc['2017']['Close']
# Out:
# Date
# 2017-01-03    116.150002
# 2017-01-04    116.019997
# 2017-01-05    116.610001
# 2017-01-06    117.910004
# 2017-01-09    118.989998
# 2017-01-10    119.110001
# 2017-01-11    119.750000
# 2017-01-12    119.250000
# 2017-01-13    119.040001
# 2017-01-17    120.000000
# 2017-01-18    119.989998
# 2017-01-19    119.779999
# 2017-01-20    120.000000
# 2017-01-23    120.080002
# 2017-01-24    119.970001
# 2017-01-25    121.879997
# 2017-01-26    121.940002
# 2017-01-27    121.949997
# 2017-01-30    121.629997
# 2017-01-31    121.349998
# 2017-02-01    128.750000
# 2017-02-02    128.529999
# 2017-02-03    129.080002
# 2017-02-06    130.289993
# 2017-02-07    131.529999
# 2017-02-08    132.039993
# 2017-02-09    132.419998
# 2017-02-10    132.119995
# 2017-02-13    133.289993
# 2017-02-14    135.020004
#                  ...
# 2017-11-16    171.100006
# 2017-11-17    170.149994
# 2017-11-20    169.979996
# 2017-11-21    173.139999
# 2017-11-22    174.960007
# ...

# %%
appl.loc['2020-02']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-02

#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  296.239990  300.600006  295.190002  300.350006  299.638885
# 2020-01-03  297.149994  300.579987  296.500000  297.429993  296.725769
# 2020-01-04  297.149994  300.579987  296.500000  297.429993  296.725769
# 2020-01-05  297.149994  300.579987  296.500000  297.429993  296.725769
# 2020-01-06  293.790009  299.959991  292.750000  299.799988  299.090149
# 2020-01-07  299.839996  300.899994  297.480011  298.390015  297.683533
# 2020-01-08  297.160004  304.440002  297.160004  303.190002  302.472137
# 2020-01-09  307.239990  310.429993  306.200012  309.630005  308.896912
# 2020-01-10  310.600006  312.670013  308.250000  310.329987  309.595215
# ...

# %%
rng=pd.date_range('01-01-2019','31-01-2019')

# %%
rng
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12',
#                '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20',
#                '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24',
#                '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng1=pd.date_range('01-01-2019','31-01-2019',freq='B')

# %%
rng1
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22',
#                '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
import matplotlib.pyplot as plt

# %%
app['Close'].plot()

# %%
app1=app.resample(fill_method='pad',rule='W')
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).pad()
#   """Entry point for launching an IPython kernel.

# %%
app1['Close'].plot()

# %%
app2=app.resample(fill_method='pad',rule='M')
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).pad()
#   """Entry point for launching an IPython kernel.

# %%
app2['Close'].plot()

# %%
L=[10,20,30,40,50]

# %%
df=pd.DataFrame(L)

# %%
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
df.rolling(window=3).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2  20.0
# 3  30.0
# 4  40.0

# %%
df.sum
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.rolling(window=3).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2  20.0
# 3  30.0
# 4  40.0

# %%
df.rolling(window=3,min_periods=2).mean()
# Out:
#       0
# 0   NaN
# 1  15.0
# 2  20.0
# 3  30.0
# 4  40.0

# %%
df.rolling(window=3,min_periods=1).mean()
# Out:
#       0
# 0  10.0
# 1  15.0
# 2  20.0
# 3  30.0
# 4  40.0

# %%
d_range=pd.date_range('01-01-2020','28-02-2020',periods=20)

# %%
d_range
# Out:
# DatetimeIndex([          '2020-01-01 00:00:00',
#                '2020-01-04 01:15:47.368421052',
#                '2020-01-07 02:31:34.736842105',
#                '2020-01-10 03:47:22.105263157',
#                '2020-01-13 05:03:09.473684210',
#                '2020-01-16 06:18:56.842105263',
#                '2020-01-19 07:34:44.210526315',
#                '2020-01-22 08:50:31.578947368',
#                '2020-01-25 10:06:18.947368421',
#                '2020-01-28 11:22:06.315789473',
#                '2020-01-31 12:37:53.684210526',
#                '2020-02-03 13:53:41.052631579',
#                '2020-02-06 15:09:28.421052631',
#                '2020-02-09 16:25:15.789473684',
#                '2020-02-12 17:41:03.157894737',
#                '2020-02-15 18:56:50.526315789',
#                '2020-02-18 20:12:37.894736842',
#                '2020-02-21 21:28:25.263157894',
#                '2020-02-24 22:44:12.631578947',
# ...

# %%
d_range=pd.date_range('01-01-2020',periods=20,freq='M')

# %%
d_range
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
d_range=pd.date_range(start='01-01-2020',periods=24,freq='H')

# %%
d_range
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                '2020-01-01 10:00:00', '2020-01-01 11:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 13:00:00',
#                '2020-01-01 14:00:00', '2020-01-01 15:00:00',
#                '2020-01-01 16:00:00', '2020-01-01 17:00:00',
#                '2020-01-01 18:00:00', '2020-01-01 19:00:00',
#                '2020-01-01 20:00:00', '2020-01-01 21:00:00',
#                '2020-01-01 22:00:00', '2020-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')
